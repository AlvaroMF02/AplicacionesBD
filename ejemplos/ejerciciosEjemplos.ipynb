# %%
import csv

with open("csvEjem.csv", "r", newline="", encoding="utf-8") as archivo:
    lector = csv.reader(archivo)
    
    for fila in lector:
        print(fila)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[1], line 6
#       3 with open("csvEjem.csv", "r", newline="", encoding="utf-8") as archivo:
#       4     lector = csv.reader(archivo)
# ----> 6     for fila in lector:
#       7         print(fila)
#
# File <frozen codecs>:322, in decode(self, input, final)
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x8d in position 11: invalid start byte

# %%
import json
from pprint import pprint

with open("ejem.json", "r", encoding="utf-8") as archivo:
    datos = json.load(archivo)

pprint(datos)
# Out:
# {'cliente': {'correo': 'janedoe@email.com',
#              'nombre': 'Jane Doe',
#              'telefono': None},
#  'delivery': True,
#  'precio': 15.67,
#  'queso_extra': False,
#  'tamano': 'mediana',
#  'toppings': ['champinones', 'pepperoni', 'albahaca']}

# %%
import xml.etree.ElementTree as ET
tree = ET.parse('data.xml')
root = tree.getroot()

for child in root:
    # print(child.tag, child.attrib)
    # print(neighbor.attrib)
    print(f"{child.tag}->{[x.tag for x in child]}")
# Out:
# country->['rank', 'year', 'gdppc', 'neighbor', 'neighbor']
# country->['rank', 'year', 'gdppc', 'neighbor']
# country->['rank', 'year', 'gdppc', 'neighbor', 'neighbor']

# %%
import feedparser
d = feedparser.parse('https://feeds.elpais.com/mrss-s/pages/ep/site/elpais.com/portada')

for x in d.entries:
    print(f"\nTitulo: \n{x.title}")
    print(x.description)
    print(x.published)
# Out:
# Titulo:
# Zelenski afirma que Trump vive en una “burbuja de desinformación” y este le llama “dictador”
# El presidente de Ucrania responde a las palabras del mandatario republicano, que culpa a su Gobierno de iniciar la guerra. El choque dialéctico tensa las relaciones entre los dos países en medio del nuevo acercamiento entre Washington y Moscú
# Wed, 19 Feb 2025 17:38:38 GMT
#
# Titulo:
# La UE aprueba nuevas sanciones a Rusia en pleno deshielo entre Washington y Moscú
# El presidente del Consejo, António Costa, inicia una ronda de contactos bilaterales para consensuar una posición común sobre Ucrania
# Wed, 19 Feb 2025 13:12:36 GMT
#
# Titulo:
# Macron se reúne con una veintena de países europeos y Canadá para ampliar la estrategia común en la guerra de Ucrania
# El malestar de esos Estados fuerza al presidente francés a convocar una segunda cita, esta vez telemática, con el resto de socios de la UE y con países extracomunitarios
# Wed, 19 Feb 2025 11:08:47 GMT
#
# Titulo:
# ...

# %%
import csv
with open('pais.csv', 'w', newline='') as f:
    writer = csv.DictWriter(f, delimiter=',', fieldnames=["Titulo", "Descripción","Fecha"] )
    writer.writeheader()
    
    for x in d.entries:
        writer.writerows(x.title)
        #writer.writerows(x.description)
        #writer.writerows(x.published)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[67], line 7
#       4 writer.writeheader()
#       6 for x in d.entries:
# ----> 7     writer.writerows(x.title)
#       8     #writer.writerows(x.description)
#       9     #writer.writerows(x.published)
#
# File /usr/lib/python3.12/csv.py:167, in DictWriter.writerows(self, rowdicts)
#     166 def writerows(self, rowdicts):
# --> 167     return self.writer.writerows(map(self._dict_to_list, rowdicts))
#
# File /usr/lib/python3.12/csv.py:157, in DictWriter._dict_to_list(self, rowdict)
#     155 def _dict_to_list(self, rowdict):
#     156     if self.extrasaction == "raise":
# --> 157         wrong_fields = rowdict.keys() - self.fieldnames
#     158         if wrong_fields:
#     159             raise ValueError("dict contains fields not in fieldnames: "
# ...
